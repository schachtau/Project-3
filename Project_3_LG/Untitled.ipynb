# %%
import pandas as pd

csv_file_path = 'jobs_in_data.csv'

# DataFrame from the CSV file
df = pd.read_csv(csv_file_path)

# Display the DataFrame
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
import matplotlib.pyplot as plt

job_title = df['job_title']
job_category = df['job_category']

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.bar(job_title, job_category, color='skyblue')
plt.xlabel('Job Title')
plt.ylabel('Job Category')
plt.title('Job Category vs. Job Title')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()

# Display the bar graph
plt.show()

# %%
job_title = df['job_title']
experience_levels = df['experience_level']
salaries_in_usd = df['salary_in_usd']

salaries_in_usd = pd.to_numeric(salaries_in_usd, errors='coerce')

desired_experience_level = 'Entry-level'

entry_level_jobs = df[df['experience_level'] == desired_experience_level]
entry_level_jobs = entry_level_jobs[['job_title', 'experience_level', 'salary_in_usd']]

entry_level_jobs
# Out:
#                   job_title experience_level  salary_in_usd
# 15             Data Analyst      Entry-level          95000
# 16             Data Analyst      Entry-level          75000
# 53         Research Analyst      Entry-level          72000
# 54         Research Analyst      Entry-level          64000
# 63             Data Analyst      Entry-level         100000
# ...                     ...              ...            ...
# 9313         Data Scientist      Entry-level          62726
# 9315         Data Scientist      Entry-level          21669
# 9328  Business Data Analyst      Entry-level          59102
# 9353         Data Scientist      Entry-level         105000
# 9354  Business Data Analyst      Entry-level         100000
#
# [496 rows x 3 columns]

# %%
job_titles = df['job_title']
experience_levels = df['experience_level']
salaries_in_usd = df['salary_in_usd']

salaries_in_usd = pd.to_numeric(salaries_in_usd, errors='coerce')

desired_experience_level = 'Entry-level'

entry_level_jobs = df[df['experience_level'] == desired_experience_level]

# Sort entry-level jobs by salary in descending order
entry_level_jobs = entry_level_jobs.sort_values(by='salary_in_usd', ascending=False)

# Display entry-level jobs and their salaries
entry_level_jobs
# Out:
#       work_year                   job_title               job_category  \
# 1156       2023           Applied Scientist  Data Science and Research
# 3038       2023          Research Scientist  Data Science and Research
# 934        2023          Research Scientist  Data Science and Research
# 4221       2023          Research Scientist  Data Science and Research
# 4223       2023          Research Scientist  Data Science and Research
# ...         ...                         ...                        ...
# 3221       2022           Research Engineer  Data Science and Research
# 4531       2023              Data Scientist  Data Science and Research
# 9205       2020                 ML Engineer    Machine Learning and AI
# 8490       2021  Machine Learning Developer    Machine Learning and AI
# 8784       2022                Data Analyst              Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...
